# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("netflix.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.shape
# Out:
# (8807, 12)

# %%
# exploding comma seperated values into rows and filling up null values for director column
df_director = df.loc[:,("show_id","director")]
df_director.fillna("Not Avaliable", inplace = True)
df_director["director"] = df_director["director"].str.split(",")
df_director = df_director.explode("director")
df_director.head()
# Out:
#   show_id         director
# 0      s1  Kirsten Johnson
# 1      s2    Not Avaliable
# 2      s3  Julien Leclercq
# 3      s4    Not Avaliable
# 4      s5    Not Avaliable

# %%
# exploding comma seperated values into rows and filling up null values for cast column
df_cast = df.loc[:,("show_id","cast")]
df_cast.fillna("Not Avaliable", inplace = True)
df_cast["cast"] = df_cast["cast"].str.split(",")
df_cast = df_cast.explode("cast")
df_cast.head()
# Out:
#   show_id             cast
# 0      s1    Not Avaliable
# 1      s2       Ama Qamata
# 1      s2      Khosi Ngema
# 1      s2    Gail Mabalane
# 1      s2   Thabang Molaba

# %%
# exploding comma seperated values into rows and filling up null values for country column
df_country = df.loc[:,("show_id","country")]
df_country.fillna("Not Avaliable", inplace = True)
df_country["country"] = df_country["country"].str.split(",")
df_country = df_country.explode("country")
df_country.head()
# Out:
#   show_id        country
# 0      s1  United States
# 1      s2   South Africa
# 2      s3  Not Avaliable
# 3      s4  Not Avaliable
# 4      s5          India

# %%
# exploding comma seperated values into rows and filling up null values for listed_in column
df_listed_in = df.loc[:, ("show_id", "listed_in")]
df_listed_in["listed_in"] = df_listed_in["listed_in"].str.split(",")
df_listed_in = df_listed_in.explode("listed_in")
df_listed_in.head()
# Out:
#   show_id               listed_in
# 0      s1           Documentaries
# 1      s2  International TV Shows
# 1      s2               TV Dramas
# 1      s2            TV Mysteries
# 2      s3          Crime TV Shows

# %%
# merging 4 newly created dataframes in one using left join
df1 = pd.merge(df_director, df_cast, on = "show_id", how = "inner").merge(df_country, on = "show_id", how = "inner").merge(df_listed_in, on = "show_id", how = "inner")
df1.head()
# Out:
#   show_id         director           cast        country  \
# 0      s1  Kirsten Johnson  Not Avaliable  United States
# 1      s2    Not Avaliable     Ama Qamata   South Africa
# 2      s2    Not Avaliable     Ama Qamata   South Africa
# 3      s2    Not Avaliable     Ama Qamata   South Africa
# 4      s2    Not Avaliable    Khosi Ngema   South Africa
#
#                 listed_in
# 0           Documentaries
# 1  International TV Shows
# 2               TV Dramas
# 3            TV Mysteries
# 4  International TV Shows

# %%
# removing columns from dataframes since they are explode[d]()
df2 = df.drop(columns = ["director", "cast", "country", "listed_in"])
df2.head()
# Out:
#   show_id     type                  title          date_added  release_year  \
# 0      s1    Movie   Dick Johnson Is Dead  September 25, 2021          2020
# 1      s2  TV Show          Blood & Water  September 24, 2021          2021
# 2      s3  TV Show              Ganglands  September 24, 2021          2021
# 3      s4  TV Show  Jailbirds New Orleans  September 24, 2021          2021
# 4      s5  TV Show           Kota Factory  September 24, 2021          2021
#
#   rating   duration                                        description
# 0  PG-13     90 min  As her father nears the end of his life, filmm...
# 1  TV-MA  2 Seasons  After crossing paths at a party, a Cape Town t...
# 2  TV-MA   1 Season  To protect his family from a powerful drug lor...
# 3  TV-MA   1 Season  Feuds, flirtations and toilet talk go down amo...
# 4  TV-MA  2 Seasons  In a city of coaching centers known to train I...

# %%
# merging all the columns
netflix = df2.merge(df1, on = "show_id", how = "inner")
netflix.head()
# Out:
#   show_id     type                 title          date_added  release_year  \
# 0      s1    Movie  Dick Johnson Is Dead  September 25, 2021          2020
# 1      s2  TV Show         Blood & Water  September 24, 2021          2021
# 2      s2  TV Show         Blood & Water  September 24, 2021          2021
# 3      s2  TV Show         Blood & Water  September 24, 2021          2021
# 4      s2  TV Show         Blood & Water  September 24, 2021          2021
#
#   rating   duration                                        description  \
# 0  PG-13     90 min  As her father nears the end of his life, filmm...
# 1  TV-MA  2 Seasons  After crossing paths at a party, a Cape Town t...
# 2  TV-MA  2 Seasons  After crossing paths at a party, a Cape Town t...
# 3  TV-MA  2 Seasons  After crossing paths at a party, a Cape Town t...
# 4  TV-MA  2 Seasons  After crossing paths at a party, a Cape Town t...
#
#           director           cast        country               listed_in
# 0  Kirsten Johnson  Not Avaliable  United States           Documentaries
# 1    Not Avaliable     Ama Qamata   South Africa  International TV Shows
# 2    Not Avaliable     Ama Qamata   South Africa               TV Dramas
# 3    Not Avaliable     Ama Qamata   South Africa            TV Mysteries
# 4    Not Avaliable    Khosi Ngema   South Africa  International TV Shows

# %%
netflix.shape
# Out:
# (202065, 12)

# %%
netflix["date_added"] = pd.to_datetime(netflix["date_added"].str.strip(), format = "%B %d, %Y")
netflix.head()
# Out:
#   show_id     type                 title date_added  release_year rating  \
# 0      s1    Movie  Dick Johnson Is Dead 2021-09-25          2020  PG-13
# 1      s2  TV Show         Blood & Water 2021-09-24          2021  TV-MA
# 2      s2  TV Show         Blood & Water 2021-09-24          2021  TV-MA
# 3      s2  TV Show         Blood & Water 2021-09-24          2021  TV-MA
# 4      s2  TV Show         Blood & Water 2021-09-24          2021  TV-MA
#
#     duration                                        description  \
# 0     90 min  As her father nears the end of his life, filmm...
# 1  2 Seasons  After crossing paths at a party, a Cape Town t...
# 2  2 Seasons  After crossing paths at a party, a Cape Town t...
# 3  2 Seasons  After crossing paths at a party, a Cape Town t...
# 4  2 Seasons  After crossing paths at a party, a Cape Town t...
#
#           director           cast        country               listed_in
# 0  Kirsten Johnson  Not Avaliable  United States           Documentaries
# 1    Not Avaliable     Ama Qamata   South Africa  International TV Shows
# 2    Not Avaliable     Ama Qamata   South Africa               TV Dramas
# 3    Not Avaliable     Ama Qamata   South Africa            TV Mysteries
# 4    Not Avaliable    Khosi Ngema   South Africa  International TV Shows

# %%
netflix["date_added"] = pd.to_datetime(netflix["release_year"], format = "%Y")
netflix.head()
# Out:
#   show_id     type                 title date_added  release_year rating  \
# 0      s1    Movie  Dick Johnson Is Dead 2020-01-01          2020  PG-13
# 1      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 2      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 3      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 4      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
#
#     duration                                        description  \
# 0     90 min  As her father nears the end of his life, filmm...
# 1  2 Seasons  After crossing paths at a party, a Cape Town t...
# 2  2 Seasons  After crossing paths at a party, a Cape Town t...
# 3  2 Seasons  After crossing paths at a party, a Cape Town t...
# 4  2 Seasons  After crossing paths at a party, a Cape Town t...
#
#           director           cast        country               listed_in
# 0  Kirsten Johnson  Not Avaliable  United States           Documentaries
# 1    Not Avaliable     Ama Qamata   South Africa  International TV Shows
# 2    Not Avaliable     Ama Qamata   South Africa               TV Dramas
# 3    Not Avaliable     Ama Qamata   South Africa            TV Mysteries
# 4    Not Avaliable    Khosi Ngema   South Africa  International TV Shows

# %%
netflix.isna().sum()
# Out:
# show_id          0
# type             0
# title            0
# date_added       0
# release_year     0
# rating          67
# duration         3
# description      0
# director         0
# cast             0
# country          0
# listed_in        0
# dtype: int64

# %%
# there are some null values in rating we can fill these values by mode of ratings of movies produced by certain director or cast
netflix[netflix["rating"].isna()]
# Out:
#        show_id     type                                              title  \
# 135172   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 135173   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 154424   s6828  TV Show                  Gargantia on the Verdurous Planet
# 154425   s6828  TV Show                  Gargantia on the Verdurous Planet
# 154426   s6828  TV Show                  Gargantia on the Verdurous Planet
# ...        ...      ...                                                ...
# 172016   s7538    Movie                               My Honor Was Loyalty
# 172017   s7538    Movie                               My Honor Was Loyalty
# 172018   s7538    Movie                               My Honor Was Loyalty
# 172019   s7538    Movie                               My Honor Was Loyalty
# 172020   s7538    Movie                               My Honor Was Loyalty
#
#        date_added  release_year rating  duration  \
# 135172 2017-01-01          2017    NaN    37 min
# 135173 2017-01-01          2017    NaN    37 min
# 154424 2013-01-01          2013    NaN  1 Season
# 154425 2013-01-01          2013    NaN  1 Season
# 154426 2013-01-01          2013    NaN  1 Season
# ...           ...           ...    ...       ...
# 172016 2015-01-01          2015    NaN   115 min
# 172017 2015-01-01          2015    NaN   115 min
# 172018 2015-01-01          2015    NaN   115 min
# 172019 2015-01-01          2015    NaN   115 min
# 172020 2015-01-01          2015    NaN   115 min
#
#                                               description         director  \
# 135172  Oprah Winfrey sits down with director Ava DuVe...    Not Avaliable
# 135173  Oprah Winfrey sits down with director Ava DuVe...    Not Avaliable
# 154424  After falling through a wormhole, a space-dwel...    Not Avaliable
# 154425  After falling through a wormhole, a space-dwel...    Not Avaliable
# 154426  After falling through a wormhole, a space-dwel...    Not Avaliable
# ...                                                   ...              ...
# 172016  Amid the chaos and horror of World War II, a c...  Alessandro Pepe
# 172017  Amid the chaos and horror of World War II, a c...  Alessandro Pepe
# 172018  Amid the chaos and horror of World War II, a c...  Alessandro Pepe
# 172019  Amid the chaos and horror of World War II, a c...  Alessandro Pepe
# 172020  Amid the chaos and horror of World War II, a c...  Alessandro Pepe
#
#                            cast        country                listed_in
# 135172            Oprah Winfrey  Not Avaliable                   Movies
# 135173             Ava DuVernay  Not Avaliable                   Movies
# 154424           Kaito Ishikawa          Japan             Anime Series
# 154425           Kaito Ishikawa          Japan   International TV Shows
# 154426          Hisako Kanemoto          Japan             Anime Series
# ...                         ...            ...                      ...
# 172016       Francesco Migliore          Italy                   Dramas
# 172017          Albrecht Weimer          Italy                   Dramas
# 172018          Giulia Dichiaro          Italy                   Dramas
# 172019   Alessandra Oriti Niosi          Italy                   Dramas
# 172020         Andreas Segeritz          Italy                   Dramas
#
# [67 rows x 12 columns]

# %%
# replacing null values of rating of movies directed by Alessandro Pepe
netflix["director"][netflix["rating"].isna()].value_counts()
# Out:
# director
# Not Avaliable      60
# Alessandro Pepe     7
# Name: count, dtype: int64

# %%
netflix[netflix["director"] == "Alessandro Pepe"]
# Out:
#        show_id   type                 title date_added  release_year rating  \
# 172014   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015    NaN
# 172015   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015    NaN
# 172016   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015    NaN
# 172017   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015    NaN
# 172018   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015    NaN
# 172019   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015    NaN
# 172020   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015    NaN
#
#        duration                                        description  \
# 172014  115 min  Amid the chaos and horror of World War II, a c...
# 172015  115 min  Amid the chaos and horror of World War II, a c...
# 172016  115 min  Amid the chaos and horror of World War II, a c...
# 172017  115 min  Amid the chaos and horror of World War II, a c...
# 172018  115 min  Amid the chaos and horror of World War II, a c...
# 172019  115 min  Amid the chaos and horror of World War II, a c...
# 172020  115 min  Amid the chaos and horror of World War II, a c...
#
#                director                     cast country listed_in
# 172014  Alessandro Pepe              Leone Frisa   Italy    Dramas
# 172015  Alessandro Pepe          Paolo Vaccarino   Italy    Dramas
# 172016  Alessandro Pepe       Francesco Migliore   Italy    Dramas
# 172017  Alessandro Pepe          Albrecht Weimer   Italy    Dramas
# 172018  Alessandro Pepe          Giulia Dichiaro   Italy    Dramas
# 172019  Alessandro Pepe   Alessandra Oriti Niosi   Italy    Dramas
# 172020  Alessandro Pepe         Andreas Segeritz   Italy    Dramas

# %% [markdown]
# Since movie produced by Alessandro Pepe is listed_in Dramas catergory find out the mode of ratings for this "Drama" category

# %%
netflix["rating"][netflix["listed_in"] == "Dramas"].value_counts()
# Out:
# rating
# TV-MA    7465
# TV-14    4208
# R        3988
# PG-13    2097
# TV-PG    1048
# PG        410
# NR        265
# TV-G       98
# NC-17      39
# UR         22
# TV-Y7      10
# Name: count, dtype: int64

# %% [markdown]
# Mode of Drama Category is TV-MA or TV - 14. Reading at at the movie description TV - MA is more suitable rating.

# %%
netflix.loc[netflix['director'] == 'Alessandro Pepe'] = netflix.loc[netflix['director'] == 'Alessandro Pepe'] .fillna("TV-MA")

# %%
netflix.loc[netflix['director'] == 'Alessandro Pepe']
# Out:
#        show_id   type                 title date_added  release_year rating  \
# 172014   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015  TV-MA
# 172015   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015  TV-MA
# 172016   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015  TV-MA
# 172017   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015  TV-MA
# 172018   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015  TV-MA
# 172019   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015  TV-MA
# 172020   s7538  Movie  My Honor Was Loyalty 2015-01-01          2015  TV-MA
#
#        duration                                        description  \
# 172014  115 min  Amid the chaos and horror of World War II, a c...
# 172015  115 min  Amid the chaos and horror of World War II, a c...
# 172016  115 min  Amid the chaos and horror of World War II, a c...
# 172017  115 min  Amid the chaos and horror of World War II, a c...
# 172018  115 min  Amid the chaos and horror of World War II, a c...
# 172019  115 min  Amid the chaos and horror of World War II, a c...
# 172020  115 min  Amid the chaos and horror of World War II, a c...
#
#                director                     cast country listed_in
# 172014  Alessandro Pepe              Leone Frisa   Italy    Dramas
# 172015  Alessandro Pepe          Paolo Vaccarino   Italy    Dramas
# 172016  Alessandro Pepe       Francesco Migliore   Italy    Dramas
# 172017  Alessandro Pepe          Albrecht Weimer   Italy    Dramas
# 172018  Alessandro Pepe          Giulia Dichiaro   Italy    Dramas
# 172019  Alessandro Pepe   Alessandra Oriti Niosi   Italy    Dramas
# 172020  Alessandro Pepe         Andreas Segeritz   Italy    Dramas

# %%
netflix["rating"][netflix["listed_in"] == "Anime Series"].value_counts()
# Out:
# rating
# TV-MA    899
# TV-14    871
# TV-Y7    298
# TV-PG    210
# TV-Y      13
# Name: count, dtype: int64

# %%
netflix[netflix["rating"].isna()]
netflix.loc[netflix['show_id'] == 's6828'] = netflix.loc[netflix['show_id'] == 's6828'].fillna("TV-MA")

# %%
netflix["rating"][netflix["listed_in"] == "Kids' TV"].value_counts()
# Out:
# rating
# TV-Y7       2005
# TV-Y        1081
# TV-PG        378
# TV-G         330
# TV-Y7-FV       8
# Name: count, dtype: int64

# %%
netflix.loc[netflix['show_id'] == 's7313'] = netflix.loc[netflix['show_id'] == 's7313'].fillna("TV-Y7")

# %%
netflix[netflix["cast"] == "Oprah Winfrey"]
# Out:
#        show_id   type                                              title  \
# 89508    s3757  Movie                Oprah Presents When They See Us Now
# 135172   s5990  Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
#
#        date_added  release_year rating duration  \
# 89508  2019-01-01          2019  TV-PG   61 min
# 135172 2017-01-01          2017    NaN   37 min
#
#                                               description       director  \
# 89508   Oprah Winfrey talks with the exonerated men on...   Mark Ritchie
# 135172  Oprah Winfrey sits down with director Ava DuVe...  Not Avaliable
#
#                  cast        country      listed_in
# 89508   Oprah Winfrey  United States  Documentaries
# 135172  Oprah Winfrey  Not Avaliable         Movies

# %%
netflix.loc[netflix['show_id'] == 's5990'] = netflix.loc[netflix['show_id'] == 's5990'].fillna("TV-PG")

# %%
netflix.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# date_added      0
# release_year    0
# rating          0
# duration        3
# description     0
# director        0
# cast            0
# country         0
# listed_in       0
# dtype: int64

# %%
netflix[netflix["duration"].isna()]
# Out:
#        show_id   type                                 title date_added  \
# 126582   s5542  Movie                       Louis C.K. 2017 2017-01-01
# 131648   s5795  Movie                 Louis C.K.: Hilarious 2010-01-01
# 131782   s5814  Movie  Louis C.K.: Live at the Comedy Store 2015-01-01
#
#         release_year  rating duration  \
# 126582          2017  74 min      NaN
# 131648          2010  84 min      NaN
# 131782          2015  66 min      NaN
#
#                                               description    director  \
# 126582  Louis C.K. muses on religion, eternal love, gi...  Louis C.K.
# 131648  Emmy-winning comedy writer Louis C.K. brings h...  Louis C.K.
# 131782  The comic puts his trademark hilarious/thought...  Louis C.K.
#
#               cast        country listed_in
# 126582  Louis C.K.  United States    Movies
# 131648  Louis C.K.  United States    Movies
# 131782  Louis C.K.  United States    Movies

# %%
netflix.loc[netflix["director"] ==  "Louis C.K."]
# Out:
#        show_id   type                                 title date_added  \
# 126582   s5542  Movie                       Louis C.K. 2017 2017-01-01
# 131648   s5795  Movie                 Louis C.K.: Hilarious 2010-01-01
# 131782   s5814  Movie  Louis C.K.: Live at the Comedy Store 2015-01-01
#
#         release_year  rating duration  \
# 126582          2017  74 min      NaN
# 131648          2010  84 min      NaN
# 131782          2015  66 min      NaN
#
#                                               description    director  \
# 126582  Louis C.K. muses on religion, eternal love, gi...  Louis C.K.
# 131648  Emmy-winning comedy writer Louis C.K. brings h...  Louis C.K.
# 131782  The comic puts his trademark hilarious/thought...  Louis C.K.
#
#               cast        country listed_in
# 126582  Louis C.K.  United States    Movies
# 131648  Louis C.K.  United States    Movies
# 131782  Louis C.K.  United States    Movies

# %% [markdown]
# Rating column should be in duration and rating should be null or fillna("TV-MA") (since most of content is TV-MA)

# %%
netflix.loc[netflix["director"] ==  "Louis C.K.", "duration"] = netflix.loc[netflix["director"] ==  "Louis C.K.", "rating"]
netflix.loc[netflix["director"] ==  "Louis C.K.", "rating"] = "TV-MA"

# %%
netflix.loc[netflix["director"] ==  "Louis C.K."]
# Out:
#        show_id   type                                 title date_added  \
# 126582   s5542  Movie                       Louis C.K. 2017 2017-01-01
# 131648   s5795  Movie                 Louis C.K.: Hilarious 2010-01-01
# 131782   s5814  Movie  Louis C.K.: Live at the Comedy Store 2015-01-01
#
#         release_year rating duration  \
# 126582          2017  TV-MA   74 min
# 131648          2010  TV-MA   84 min
# 131782          2015  TV-MA   66 min
#
#                                               description    director  \
# 126582  Louis C.K. muses on religion, eternal love, gi...  Louis C.K.
# 131648  Emmy-winning comedy writer Louis C.K. brings h...  Louis C.K.
# 131782  The comic puts his trademark hilarious/thought...  Louis C.K.
#
#               cast        country listed_in
# 126582  Louis C.K.  United States    Movies
# 131648  Louis C.K.  United States    Movies
# 131782  Louis C.K.  United States    Movies

# %%
netflix.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# date_added      0
# release_year    0
# rating          0
# duration        0
# description     0
# director        0
# cast            0
# country         0
# listed_in       0
# dtype: int64

# %%
netflix.head()
# Out:
#   show_id     type                 title date_added  release_year rating  \
# 0      s1    Movie  Dick Johnson Is Dead 2020-01-01          2020  PG-13
# 1      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 2      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 3      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 4      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
#
#     duration                                        description  \
# 0     90 min  As her father nears the end of his life, filmm...
# 1  2 Seasons  After crossing paths at a party, a Cape Town t...
# 2  2 Seasons  After crossing paths at a party, a Cape Town t...
# 3  2 Seasons  After crossing paths at a party, a Cape Town t...
# 4  2 Seasons  After crossing paths at a party, a Cape Town t...
#
#           director           cast        country               listed_in
# 0  Kirsten Johnson  Not Avaliable  United States           Documentaries
# 1    Not Avaliable     Ama Qamata   South Africa  International TV Shows
# 2    Not Avaliable     Ama Qamata   South Africa               TV Dramas
# 3    Not Avaliable     Ama Qamata   South Africa            TV Mysteries
# 4    Not Avaliable    Khosi Ngema   South Africa  International TV Shows

# %%
# Stripping the Extra spaces in data
netflix.loc[:, "director"] = netflix.loc[:, "director"].str.strip()
netflix.loc[:, "cast"] = netflix.loc[:, "cast"].str.strip()
netflix.loc[:, "country"] = netflix.loc[:, "country"].str.strip()
netflix.loc[:, "listed_in"] = netflix.loc[:, "listed_in"].str.strip()
netflix.loc[:, "title"] = netflix.loc[:, "title"].str.strip()

# %%
netflix.head()
# Out:
#   show_id     type                 title date_added  release_year rating  \
# 0      s1    Movie  Dick Johnson Is Dead 2020-01-01          2020  PG-13
# 1      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 2      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 3      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
# 4      s2  TV Show         Blood & Water 2021-01-01          2021  TV-MA
#
#     duration                                        description  \
# 0     90 min  As her father nears the end of his life, filmm...
# 1  2 Seasons  After crossing paths at a party, a Cape Town t...
# 2  2 Seasons  After crossing paths at a party, a Cape Town t...
# 3  2 Seasons  After crossing paths at a party, a Cape Town t...
# 4  2 Seasons  After crossing paths at a party, a Cape Town t...
#
#           director           cast        country               listed_in
# 0  Kirsten Johnson  Not Avaliable  United States           Documentaries
# 1    Not Avaliable     Ama Qamata   South Africa  International TV Shows
# 2    Not Avaliable     Ama Qamata   South Africa               TV Dramas
# 3    Not Avaliable     Ama Qamata   South Africa            TV Mysteries
# 4    Not Avaliable    Khosi Ngema   South Africa  International TV Shows

# %%
# Splitting the dataframe into 2 type 1st Movies, 2nd TV Show
df_movies = netflix.loc[netflix["type"] == "Movie"].reset_index()
df_shows = netflix.loc[netflix["type"] == "TV Show"].reset_index()
netflix = pd.concat([df_movies, df_shows], axis=0).reset_index()

# %%
# fixing duration column in df_movie
df_movies["duration"] = df_movies["duration"].str.split(" ")
df_movies["duration"] = int(df_movies["duration"][0][0])

# %%
df_movies.head()
# Out:
#    index show_id   type                             title date_added  \
# 0      0      s1  Movie              Dick Johnson Is Dead 2020-01-01
# 1    159      s7  Movie  My Little Pony: A New Generation 2021-01-01
# 2    160      s7  Movie  My Little Pony: A New Generation 2021-01-01
# 3    161      s7  Movie  My Little Pony: A New Generation 2021-01-01
# 4    162      s7  Movie  My Little Pony: A New Generation 2021-01-01
#
#    release_year rating  duration  \
# 0          2020  PG-13        90
# 1          2021     PG        90
# 2          2021     PG        90
# 3          2021     PG        90
# 4          2021     PG        90
#
#                                          description         director  \
# 0  As her father nears the end of his life, filmm...  Kirsten Johnson
# 1  Equestria's divided. But a bright-eyed hero be...    Robert Cullen
# 2  Equestria's divided. But a bright-eyed hero be...    Robert Cullen
# 3  Equestria's divided. But a bright-eyed hero be...    Robert Cullen
# 4  Equestria's divided. But a bright-eyed hero be...    Robert Cullen
#
#               cast        country                 listed_in
# 0    Not Avaliable  United States             Documentaries
# 1  Vanessa Hudgens  Not Avaliable  Children & Family Movies
# 2     Kimiko Glenn  Not Avaliable  Children & Family Movies
# 3    James Marsden  Not Avaliable  Children & Family Movies
# 4     Sofia Carson  Not Avaliable  Children & Family Movies

# %%
# fixing duration column in df_shows
df_shows["duration"] = df_shows["duration"].str.split(" ")
df_shows["duration"] = int(df_shows["duration"][0][0])

# %%
df_shows.head()
# Out:
#    index show_id     type          title date_added  release_year rating  \
# 0      1      s2  TV Show  Blood & Water 2021-01-01          2021  TV-MA
# 1      2      s2  TV Show  Blood & Water 2021-01-01          2021  TV-MA
# 2      3      s2  TV Show  Blood & Water 2021-01-01          2021  TV-MA
# 3      4      s2  TV Show  Blood & Water 2021-01-01          2021  TV-MA
# 4      5      s2  TV Show  Blood & Water 2021-01-01          2021  TV-MA
#
#    duration                                        description       director  \
# 0         2  After crossing paths at a party, a Cape Town t...  Not Avaliable
# 1         2  After crossing paths at a party, a Cape Town t...  Not Avaliable
# 2         2  After crossing paths at a party, a Cape Town t...  Not Avaliable
# 3         2  After crossing paths at a party, a Cape Town t...  Not Avaliable
# 4         2  After crossing paths at a party, a Cape Town t...  Not Avaliable
#
#           cast       country               listed_in
# 0   Ama Qamata  South Africa  International TV Shows
# 1   Ama Qamata  South Africa               TV Dramas
# 2   Ama Qamata  South Africa            TV Mysteries
# 3  Khosi Ngema  South Africa  International TV Shows
# 4  Khosi Ngema  South Africa               TV Dramas

# %% [markdown]
# Data Cleaning and Exploration:
# How many missing values exist in each column and how will they be handled?
# Are there any duplicate records in the dataset? If yes, how many?
# What are the data types of each column? Are there any columns with incorrect data types that need to be converted for further analysis?
#
# Top Shows/Movies Analysis:
# Which are the top 10 rated shows/movies in the dataset?
# What are the most common genres of shows/movies available on Netflix? How are they distributed?
# How do ratings vary across different genres?
#
# Time Analysis:
# What is the trend in the number of shows/movies released over the years?
# How has the frequency of shows/movies being added to Netflix changed over time?
# Is there a particular time of the year when more shows/movies are added?
#
# Recommendations and Insights:
# Based on genres, which types of shows/movies should Netflix consider adding more of?
# Are there seasonal trends in the popularity of certain genres of shows/movies?
#
# Additional Analysis:
# What is the typical duration of shows/movies on Netflix? How does this vary by genre?
# Which countries produce the most content for Netflix? How does content popularity vary by country?
# Presentation and Communication:
# Which type of visualization would best represent each of the insights gathered from the data?
# How can data storytelling be applied to present the case study effectively to a non-technical audience?

# %%
netflix.drop(columns = ["level_0", "index"], inplace = True)

# %%
netflix.head()
# Out:
#   show_id   type                             title date_added  release_year  \
# 0      s1  Movie              Dick Johnson Is Dead 2020-01-01          2020
# 1      s7  Movie  My Little Pony: A New Generation 2021-01-01          2021
# 2      s7  Movie  My Little Pony: A New Generation 2021-01-01          2021
# 3      s7  Movie  My Little Pony: A New Generation 2021-01-01          2021
# 4      s7  Movie  My Little Pony: A New Generation 2021-01-01          2021
#
#   rating duration                                        description  \
# 0  PG-13   90 min  As her father nears the end of his life, filmm...
# 1     PG   91 min  Equestria's divided. But a bright-eyed hero be...
# 2     PG   91 min  Equestria's divided. But a bright-eyed hero be...
# 3     PG   91 min  Equestria's divided. But a bright-eyed hero be...
# 4     PG   91 min  Equestria's divided. But a bright-eyed hero be...
#
#           director             cast        country                 listed_in
# 0  Kirsten Johnson    Not Avaliable  United States             Documentaries
# 1    Robert Cullen  Vanessa Hudgens  Not Avaliable  Children & Family Movies
# 2    Robert Cullen     Kimiko Glenn  Not Avaliable  Children & Family Movies
# 3    Robert Cullen    James Marsden  Not Avaliable  Children & Family Movies
# 4    Robert Cullen     Sofia Carson  Not Avaliable  Children & Family Movies
